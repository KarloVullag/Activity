# %% [markdown]
# <a href="https://colab.research.google.com/github/KarloVullag/Activity/blob/Final-exam(may-24)/FinalExam1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

# Prior: Beta(2, 2)
a_prior = 2
b_prior = 2

# Data: 10 food insecure out of 15
successes = 10
failures = 5

# Posterior: Beta(2+10, 2+5) = Beta(12, 7)
a_post = a_prior + successes
b_post = b_prior + failures

x = np.linspace(0, 1, 1000)
plt.plot(x, beta.pdf(x, a_post, b_post), label='Posterior Beta(12, 7)')
plt.plot(x, beta.pdf(x, a_prior, b_prior), linestyle='--', label='Prior Beta(2, 2)')
plt.title('Bayesian Update: Food Insecurity')
plt.xlabel('Probability of Insecurity')
plt.ylabel('Density')
plt.legend()
plt.grid()
plt.show()
